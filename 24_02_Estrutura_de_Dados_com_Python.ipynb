# %% [markdown]
# <a href="https://colab.research.google.com/github/camilacampos-jpg/Menu-interativo-em-Python-Augusto-Ortolan-/blob/main/24_02_Estrutura_de_Dados_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"olá mundo"
# Out:
# 'olá mundo'

# %%
print("olá mundo")
# Out:
# olá mundo

# %%
# variaveis (= atribuição)

nome = "Camila" # string
idade = 30 # int
altura = 1.66 # float
Status = True # bool

# operadorees aritmeticos
# + soma
# * multiplicação
# - subtração
# / divisão
# // divisão inteira
# % resto

# NOTA: A integração com GitHub no Colab é feita pelos menus 'Arquivo > Salvar uma cópia no GitHub...' ou 'Arquivo > Abrir notebook > GitHub'.
